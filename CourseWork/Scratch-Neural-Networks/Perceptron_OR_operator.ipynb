# %% [markdown]
# <a href="https://colab.research.google.com/github/Andre-Williams22/DS-2.2-Deep-Learning/blob/master/CourseWork/Scratch-Neural-Networks/Perceptron_OR_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptron OR operator

# %% [markdown]
# ## Inputs, outputs and weights

# %%
import numpy as np

# %%
inputs = np.array([[0,0], [0,1], [1,0], [1,1]])

# %%
outputs = np.array([0, 1, 1, 0])

# %%
weights = np.array([0.0, 0.0])

# %%
learning_rate = 0.1

# %% [markdown]
# ## Step function

# %%
def step_function(sum):
  if (sum >= 1):
    return 1
  return 0

# %% [markdown]
# ## Calculate output

# %%
def calculate_output(instance):
  s = instance.dot(weights)
  return step_function(s)

# %% [markdown]
# ## Train

# %%
def train():
  total_error = 1
  while (total_error != 0):
    total_error = 0
    for i in range(len(outputs)):
      prediction = calculate_output(inputs[i])
      error = abs(outputs[i] - prediction)
      total_error += error
      if error > 0:
        for j in range(len(weights)):
          weights[j] = weights[j] + (learning_rate * inputs[i][j] * error)
          print('Weight updated: ' + str(weights[j]))  
    print('Total error: ' + str(total_error))

# %%
train()
# Out:
# Streaming output truncated to the last 5000 lines.
# Weight updated: 13183.60000003043
# Weight updated: 13183.60000003043
# Total error: 1
# Weight updated: 13183.70000003043
# Weight updated: 13183.70000003043
# Total error: 1
# Weight updated: 13183.800000030431
# Weight updated: 13183.800000030431
# Total error: 1
# Weight updated: 13183.900000030431
# Weight updated: 13183.900000030431
# Total error: 1
# Weight updated: 13184.000000030432
# Weight updated: 13184.000000030432
# Total error: 1
# Weight updated: 13184.100000030432
# Weight updated: 13184.100000030432
# Total error: 1
# Weight updated: 13184.200000030432
# Weight updated: 13184.200000030432
# Total error: 1
# Weight updated: 13184.300000030433
# Weight updated: 13184.300000030433
# Total error: 1
# Weight updated: 13184.400000030433
# Weight updated: 13184.400000030433
# Total error: 1
# Weight updated: 13184.500000030434
# Weight updated: 13184.500000030434
# Total error: 1
# Weight updated: 13184.600000030434
# ...

# %% [markdown]
# ## Classification

# %%
weights
# Out:
# array([1.1, 1.1])

# %%
calculate_output(np.array([0, 0]))
# Out:
# 0

# %%
calculate_output(np.array([0, 1]))
# Out:
# 1

# %%
calculate_output(np.array([1, 0]))
# Out:
# 1

# %%
calculate_output(np.array([1, 1]))
# Out:
# 1
